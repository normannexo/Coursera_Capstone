# %%
import numpy as np # library to handle data in a vectorized manner
from bs4 import BeautifulSoup

# use module dotenv to manage API keys and secrets
import os
# %load_ext dotenv
# %dotenv

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.geocoders import ArcGIS # convert an address into latitude and longitude values


import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Data gathering
# Collect data from wikipedia:

# %%
wiki_url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
website_url = requests.get(wiki_url).text
soup = BeautifulSoup(website_url,'html.parser')
table = soup.find('table', attrs={'class':'wikitable sortable'})
rows = table.find_all('tr')[1:]
list_codes = []
for row in rows:
    cols = row.find_all('td')
    list_codes.append({'PostalCode':cols[0].text, 'Borough':cols[1].text, 'Neighbourhood':cols[2].text})

df_nbh = pd.DataFrame(list_codes)
df_nbh.Neighbourhood = df_nbh.Neighbourhood.str.replace('\\n','')
df_nbh = df_nbh.replace({'Not assigned': np.nan})
df_nbh.dropna(inplace=True)
# initialize column with np.nan
df_nbh['location'] = np.nan
df_nbh.head()
# Out:
#   PostalCode           Borough     Neighbourhood  location
# 2        M3A        North York         Parkwoods       NaN
# 3        M4A        North York  Victoria Village       NaN
# 4        M5A  Downtown Toronto      Harbourfront       NaN
# 5        M6A        North York  Lawrence Heights       NaN
# 6        M6A        North York    Lawrence Manor       NaN

# %% [markdown]
# Add geospatial data via geopy library and save to csv:

# %%
geolocator = ArcGIS(user_agent="foursquare_agent")
df_nbh['location'] = df_nbh[df_nbh.location.isna()].apply(lambda x : geolocator.geocode(str(x['Neighbourhood']) + " " +  str(x['PostalCode'])), axis=1)
df_nbh['location'].head()

# %%
def get_longitude(location):
    try:
        return location.longitude
    except Exception:
        return np.nan
def get_latitude(location):
    try:
        return location.latitude
    except Exception:
        return np.nan
df_nbh['longitude']= df_nbh.location.apply(get_longitude)
df_nbh['latitude']= df_nbh.location.apply(get_latitude)
df_nbh.head()

# %%
df_nbh.drop(columns=['location'], inplace=True)
df_nbh.reset_index(drop=True, inplace=True)
df_nbh.to_csv("./toronto.csv")

# %%
df_toronto = pd.read_csv("./toronto.csv")
df_toronto.drop(columns=['Unnamed: 0'], inplace=True)
df_toronto.head()
# Out:
#   PostalCode           Borough     Neighbourhood   longitude   latitude
# 0        M3A        North York         Parkwoods  -79.329242  43.752420
# 1        M4A        North York  Victoria Village  -79.313265  43.730600
# 2        M5A  Downtown Toronto      Harbourfront  114.191795  22.302671
# 3        M6A        North York  Lawrence Heights  -79.449943  43.714878
# 4        M6A        North York    Lawrence Manor  -79.449943  43.714878

# %%
# some of the location data are false, obviously:

indexNames = df_toronto.loc[abs(df_toronto['longitude'] + 80) > 5].index
df_toronto.drop(indexNames, inplace=True)

# %% [markdown]
# ### Create a map of Toronto with neighbourhoods superimposed

# %%
# create map of Toronto using latitude and longitude values
loc_toronto = geolocator.geocode('Toronto')

map_toronto = folium.Map(location=[loc_toronto.latitude, loc_toronto.longitude], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['latitude'], df_toronto['longitude'], df_toronto['Borough'], df_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Define Foursquare API keys and version:

# %%
client_id = os.environ.get('CLIENT_ID')
client_secret = os.environ.get('CLIENT_SECRET')
version = '20180605'

# %%
# define query function
def foursquare_query(address, endpoint, search_query, section="", cat_ids=[],radius=10000, limit=100):
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    categoryId = ''
    if (len(cat_ids)>0):
        ids = df_cats[df_cats.name.isin(cat_ids)]['id']
        categoryId = '&categoryId=' + ','.join(ids)
        print(categoryId)
       
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&ll={},{}&v={}&query={}&section={}&radius={}&limit={}{}'.format(endpoint, client_id, client_secret, latitude, longitude, version, search_query, section, radius, limit,categoryId)
    print(url)
    results = requests.get(url).json()
    #results = ""
    return results

# %% [markdown]
# ## Explore neighbourhoods

# %%
north_york_data = df_toronto[df_toronto['Borough'] == 'North York'].reset_index(drop=True)
north_york_data
# Out:
#    PostalCode     Borough        Neighbourhood  longitude   latitude
# 0         M3A  North York            Parkwoods -79.329242  43.752420
# 1         M4A  North York     Victoria Village -79.313265  43.730600
# 2         M6A  North York     Lawrence Heights -79.449943  43.714878
# 3         M6A  North York       Lawrence Manor -79.449943  43.714878
# 4         M3B  North York      Don Mills North -79.347292  43.752102
# 5         M6B  North York            Glencairn -79.446482  43.708429
# 6         M3C  North York      Flemingdon Park -79.331170  43.713090
# 7         M3C  North York      Don Mills South -79.333858  43.705680
# 8         M2H  North York    Hillcrest Village -79.356207  43.802845
# 9         M3H  North York       Bathurst Manor -79.448688  43.757875
# 10        M3H  North York      Downsview North -79.448688  43.757875
# 11        M3H  North York       Wilson Heights -79.454556  43.747927
# 12        M2J  North York           Henry Farm -79.347813  43.780970
# 13        M3J  North York      York University -79.498630  43.771700
# 14        M2K  North York      Bayview Village -79.380529  43.781015
# 15        M3K  North York          CFB Toronto -79.467320  43.738685
# 16        M3K  North York       Downsview East -79.499920  43.720188
# 17        M2L  North York         Silver Hills -77.078310  43.017010
# 18        M2L  North York           York Mills -79.391617  43.746475
# 19        M3L  North York       Downsview West -79.499920  43.720188
# 20        M6L  North York           North Park -79.473230  43.720290
# 21        M6L  North York          Upwood Park -79.500031  43.706842
# 22        M9L  North York        Humber Summit -79.573421  43.761627
# 23        M2M  North York          Newtonbrook -79.422775  43.784001
# 24        M2M  North York           Willowdale -79.410832  43.790316
# 25        M3M  North York    Downsview Central -79.499920  43.720188
# 26        M5M  North York         Bedford Park -79.408778  43.726178
# 27        M5M  North York  Lawrence Manor East -79.408346  43.723806
# 28        M9M  North York            Humberlea -79.537508  43.733705
# 29        M2N  North York     Willowdale South -79.402587  43.770896
# 30        M3N  North York  Downsview Northwest -79.519590  43.755371
# 31        M2P  North York      York Mills West -79.402866  43.744156
# 32        M2R  North York      Willowdale West -79.445797  43.777695

# %%
address = 'North York, Toronto'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of North York are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of North York are 43.7543263, -79.44911696639593.

# %%
# create map of Toronto using latitude and longitude values
map_north_york = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(north_york_data['latitude'], north_york_data['longitude'], north_york_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_north_york)

# %% [markdown]
# ## Function for getting nearby venues in a radius of 500 m

# %%
LIMIT = 5
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            client_id, 
            client_secret, 
            version, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
df_ny_venues = getNearbyVenues(names=north_york_data.Neighbourhood, latitudes=north_york_data.latitude, longitudes=north_york_data.longitude)
# Out:
# Parkwoods
# Victoria Village
# Lawrence Heights
# Lawrence Manor
# Don Mills North
# Glencairn
# Flemingdon Park
# Don Mills South
# Hillcrest Village
# Bathurst Manor
# Downsview North
# Wilson Heights
# Henry Farm
# York University
# Bayview Village
# CFB Toronto
# Downsview East
# Silver Hills
# York Mills
# Downsview West
# North Park
# Upwood Park
# Humber Summit
# Newtonbrook
# Willowdale
# Downsview Central
# Bedford Park
# Lawrence Manor East
# Humberlea
# Willowdale South
# Downsview Northwest
# York Mills West
# Willowdale West

# %%
df_ny_venues
# Out:
#             Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 
# 90                          Sharks Sports Club       43.764481
# 91                                 Hendon Park       43.781033
# 92                                   Soul Cafe       43.786887
# 93                              Busan Galmaegi       43.786347
# 94                               St.Pio Bakery       43.719869
# 95                               Jane Pharmacy       43.718161
# 96                            Pho Mi Nha Trang       43.722709
# 97                    Mackfield Transportation       43.722863
# 98                                 Pizza Depot       43.717796
# 99                             TD Canada Trust       43.727536
# 100                        Metro Newspaper Box       43.726189
# 101                              twinkle nails       43.728100
# 102                    Lawrence Subway Station       43.725847
# 103                                Zalin Shoes       43.726577
# 104                                  Starbucks       43.724878
# 105                   Otter Creek Skating Rink       43.721167
# 106                   Otter Creek Skating Park       43.721020
# 107                        Metro Newspaper Box       43.726189
# 108                                Tim Hortons       43.733757
# 109                                Tim Hortons       43.734998
# 110                         Las Brisas Del Mar       43.736365
# 111                         Joseph Bannon Park       43.732760
# 112                               Maryam Hotel       43.766961
# 113                              Parkview Park       43.775273
# 114                           Pho Com Viet Nam       43.756631
# 115                         Shoppers Drug Mart       43.756147
# 116                                  Pizza Hut       43.756340
# 117                                        KFC       43.756549
# 118                             The Beer Store       43.756094
# 119                           GoodLife Fitness       43.744871
# 120                                  Starbucks       43.744871
# 121                          The Miller Tavern       43.740835
# 122                                 Second Cup       43.744732
# 123                                Tim Hortons       43.744928
# 124                                Tim Hortons       43.780940
# 125                               Antibes Park       43.778872
# 126                       Got to half it Baby!       43.778242
# 127                           Belle Restaurant       43.774325
# 128                      TTC Bus 36 Finch West       43.773875
#
#      Venue Longitude                            Venue Category
# 0         -79.332140                                      Park
# 1         -79.333114                         Food & Drink Shop
# 2         -79.310771                                      Park
# 3         -79.312427                             Grocery Store
# 4         -79.307520                         German Restaurant
# 5         -79.455296                      Fast Food Restaurant
# 6         -79.447185                               Coffee Shop
# 7         -79.445926                                 Pet Store
# 8         -79.446830                               Gas Station
# 9         -79.447515                      Fast Food Restaurant
# 10        -79.455296                      Fast Food Restaurant
# 11        -79.447185                               Coffee Shop
# 12        -79.445926                                 Pet Store
# 13        -79.446830                               Gas Station
# 14        -79.447515                      Fast Food Restaurant
# 15        -79.349518                               Supermarket
# 16        -79.348498                 Middle Eastern Restaurant
# 17        -79.342741                               Golf Course
# 18        -79.350110                               Pizza Place
# 19        -79.351894                  Mediterranean Restaurant
# 20        -79.443930                       Japanese Restaurant
# 21        -79.442536                             Grocery Store
# 22        -79.442378                                       Pub
# 23        -79.442658                               Pizza Place
# 24        -79.333702                             Grocery Store
# 25        -79.334296                      Pakistani Restaurant
# 26        -79.335000                       Japanese Restaurant
# 27        -79.334223                                  Pharmacy
# 28        -79.333817                      Fast Food Restaurant
# 29        -79.334434                         Convenience Store
# 30        -79.335969                                     Trail
# 31        -79.333444                                      Park
# 32        -79.335958                              Liquor Store
# 33        -79.334456                             Hot Dog Joint
# 34        -79.354347  Residential Building (Apartment / Condo)
# 35        -79.360695                                   Dog Run
# 36        -79.450400                               Men's Store
# 37        -79.450400                               Men's Store
# 38        -79.457446                         French Restaurant
# 39        -79.455591                       American Restaurant
# 40        -79.456907                               Gas Station
# 41        -79.456392                               Pizza Place
# 42        -79.456485                               Coffee Shop
# 43        -79.343483                          Toy / Game Store
# 44        -79.344085                             Movie Theater
# 45        -79.346526                                   Theater
# 46        -79.343665                             Shopping Mall
# 47        -79.345263                                  Tea Room
# 48        -79.501941                           Thai Restaurant
# 49        -79.502217                               Coffee Shop
# 50        -79.501292                               Coffee Shop
# 51        -79.500094                               Coffee Shop
# 52        -79.503403                               Coffee Shop
# 53        -79.380599                Construction & Landscaping
# 54        -79.379326                                     Trail
# 55        -79.383108                                      Park
# 56        -79.382422                                   Dog Run
# 57        -79.382417                        Golf Driving Range
# 58        -79.470111                                   Airport
# 59        -79.472242                               Coffee Shop
# 60        -79.471144                                Food Court
# 61        -79.464777                                      Park
# 62        -79.502625                                    Bakery
# 63        -79.501301                                  Pharmacy
# 64        -79.498058                     Vietnamese Restaurant
# 65        -79.498078                          Business Service
# 66        -79.503762                               Pizza Place
# 67        -79.391470                        Athletics & Sports
# 68        -79.391695                          Dentist's Office
# 69        -79.390855                                      Park
# 70        -79.385595                               Supermarket
# 71        -79.396413                                  Bus Stop
# 72        -79.502625                                    Bakery
# 73        -79.501301                                  Pharmacy
# 74        -79.498058                     Vietnamese Restaurant
# 75        -79.498078                          Business Service
# 76        -79.503762                               Pizza Place
# 77        -79.468472                     Vietnamese Restaurant
# 78        -79.474341                                 Pet Store
# 79        -79.467995                               Coffee Shop
# 80        -79.468513                                 Gift Shop
# 81        -79.467525                                Shoe Store
# 82        -79.504426                               Gas Station
# 83        -79.504504                         Convenience Store
# 84        -79.504790                     Vietnamese Restaurant
# 85        -79.504261                        Mexican Restaurant
# 86        -79.576336                        Mexican Restaurant
# 87        -79.576024                               Coffee Shop
# 88        -79.571376                                      Park
# 89        -79.571689                                    Bakery
# 90        -79.574330                                Sports Bar
# 91        -79.420505                                Playground
# 92        -79.418165                                      Café
# 93        -79.417530                         Korean Restaurant
# 94        -79.502625                                    Bakery
# 95        -79.501301                                  Pharmacy
# 96        -79.498058                     Vietnamese Restaurant
# 97        -79.498078                          Business Service
# 98        -79.503762                               Pizza Place
# 99        -79.403157                                      Bank
# 100       -79.404911                                 Bookstore
# 101       -79.405098                                       Spa
# 102       -79.402678                             Metro Station
# 103       -79.402637                                Shoe Store
# 104       -79.402490                               Coffee Shop
# 105       -79.409853                              Skating Rink
# 106       -79.409828                              Skating Rink
# 107       -79.404911                                 Bookstore
# 108       -79.536615                               Coffee Shop
# 109       -79.533813                               Coffee Shop
# 110       -79.534895                                 Nightclub
# 111       -79.532351                                      Park
# 112       -79.401199                                     Hotel
# 113       -79.402317                                Playground
# 114       -79.518336                     Vietnamese Restaurant
# 115       -79.515843                                  Pharmacy
# 116       -79.517818                               Pizza Place
# 117       -79.519042                      Fast Food Restaurant
# 118       -79.516239                                Beer Store
# 119       -79.406289                                       Gym
# 120       -79.406289                               Coffee Shop
# 121       -79.405729                                       Pub
# 122       -79.406180                               Coffee Shop
# 123       -79.405924                               Coffee Shop
# 124       -79.444231                               Coffee Shop
# 125       -79.448705                                      Park
# 126       -79.450862                                Baby Store
# 127       -79.442651               Eastern European Restaurant
# 128       -79.443284                                  Bus Line
