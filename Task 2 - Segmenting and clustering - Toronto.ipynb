# %% [markdown]
# ## Segmenting and clustering neighborhoods - Toronto
# ## Task 2 - getting geospatial data
# ### See section "Geospatial data" for the code for getting location data
#
# The first few cells are a repetition from task 1.
#
# Importing the libraries including BeautifulSoup for web scraping tasks:

# %%
import numpy as np # library to handle data in a vectorized manner
from bs4 import BeautifulSoup

# use module dotenv to manage API keys and secrets
import os
# %load_ext dotenv
# %dotenv

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.geocoders import ArcGIS # convert an address into latitude and longitude values


import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Data gathering
# Collect data from wikipedia with beautiful soup:

# %%
wiki_url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
website_url = requests.get(wiki_url).text
soup = BeautifulSoup(website_url,'html.parser')
table = soup.find('table', attrs={'class':'wikitable sortable'})
rows = table.find_all('tr')[1:]
list_codes = []
for row in rows:
    cols = row.find_all('td')
    list_codes.append({'PostalCode':cols[0].text, 'Borough':cols[1].text, 'Neighborhood':cols[2].text})

df_nbh = pd.DataFrame(list_codes)

# there are line breaks in the neighborhood column, get rid of them:
df_nbh.Neighborhood = df_nbh.Neighborhood.str.replace('\\n','')

# drop not assigned boroughs
df_nbh = df_nbh.replace({'Not assigned': np.nan})
df_nbh.dropna(subset = ['Borough'],inplace=True)

#reset index:
df_nbh.reset_index(drop=True, inplace = True)
df_nbh.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M6A        North York  Lawrence Heights
# 4        M6A        North York    Lawrence Manor

# %% [markdown]
# #### group the data by the first 2 columns and combine the neighborhood values into a comma seperated string:

# %%
df_nbh = df_nbh.groupby(['PostalCode', 'Borough'], as_index=False).apply(lambda x: ', '.join(map(str,list(x.Neighborhood)))).reset_index()
df_nbh.rename(columns={0:'Neighborhood'}, inplace= True)
df_nbh.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# replace missing neighborhood data with borough:

# %%
# replace missing Neighborhood data with Borough:
df_nbh.loc[df_nbh.Neighborhood == 'nan', 'Neighborhood' ] = df_nbh.Borough
df_nbh.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
df_nbh.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Geospatial data
# ArcGIS turned out to be the most reliable geocoding service in the geopy library:

# %%
geolocator = ArcGIS(user_agent="toronto_neighborhood")
# initialize location column:
df_nbh['location'] = np.nan
df_nbh['location'] = df_nbh[df_nbh.location.isna()].apply(lambda x : geolocator.geocode( "Toronto, Ontario,  " +  str(x['PostalCode'])), axis=1)
df_nbh['location'].head()
# Out:
# 0    (M1B, (43.811525000000074, -79.19551746399998))
# 1     (M1C, (43.78566500000005, -79.15872457299997))
# 2     (M1E, (43.76581500000003, -79.17519294699997))
# 3    (M1G, (43.768369121000035, -79.21758999999997))
# 4     (M1H, (43.76968799900004, -79.23943999999995))
# Name: location, dtype: object

# %%
# are there any nans left?
df_nbh['location'].isna().sum()
# Out:
# 0

# %% [markdown]
# now we need to create the columns for longitude and latitude:

# %%
# defining functions to use in apply
def get_longitude(location):
    try:
        return location.longitude
    except Exception:
        return np.nan
def get_latitude(location):
    try:
        return location.latitude
    except Exception:
        return np.nan
    
# use apply to fill the new columns:
df_nbh['Longitude']= df_nbh.location.apply(get_longitude)
df_nbh['Latitude']= df_nbh.location.apply(get_latitude)
df_nbh.head()
# Out:
#   PostalCode      Borough                            Neighborhood  \
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae
#
#                                           location  Longitude   Latitude
# 0  (M1B, (43.811525000000074, -79.19551746399998)) -79.195517  43.811525
# 1   (M1C, (43.78566500000005, -79.15872457299997)) -79.158725  43.785665
# 2   (M1E, (43.76581500000003, -79.17519294699997)) -79.175193  43.765815
# 3  (M1G, (43.768369121000035, -79.21758999999997)) -79.217590  43.768369
# 4   (M1H, (43.76968799900004, -79.23943999999995)) -79.239440  43.769688

# %%
df_nbh.drop(columns=['location'], inplace=True)
df_nbh.reset_index(drop=True, inplace=True)

# %%
df_nbh
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# 30         M3K        North York
# 31         M3L        North York
# 32         M3M        North York
# 33         M3N        North York
# 34         M4A        North York
# 35         M4B         East York
# 36         M4C         East York
# 37         M4E      East Toronto
# 38         M4G         East York
# 39         M4H         East York
# 40         M4J         East York
# 41         M4K      East Toronto
# 42         M4L      East Toronto
# 43         M4M      East Toronto
# 44         M4N   Central Toronto
# 45         M4P   Central Toronto
# 46         M4R   Central Toronto
# 47         M4S   Central Toronto
# 48         M4T   Central Toronto
# 49         M4V   Central Toronto
# 50         M4W  Downtown Toronto
# 51         M4X  Downtown Toronto
# 52         M4Y  Downtown Toronto
# 53         M5A  Downtown Toronto
# 54         M5B  Downtown Toronto
# 55         M5C  Downtown Toronto
# 56         M5E  Downtown Toronto
# 57         M5G  Downtown Toronto
# 58         M5H  Downtown Toronto
# 59         M5J  Downtown Toronto
# 60         M5K  Downtown Toronto
# 61         M5L  Downtown Toronto
# 62         M5M        North York
# 63         M5N   Central Toronto
# 64         M5P   Central Toronto
# 65         M5R   Central Toronto
# 66         M5S  Downtown Toronto
# 67         M5T  Downtown Toronto
# 68         M5V  Downtown Toronto
# 69         M5W  Downtown Toronto
# 70         M5X  Downtown Toronto
# 71         M6A        North York
# 72         M6B        North York
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A  Downtown Toronto
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A      Queen's Park
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood  Longitude   Latitude
# 0                                       Rouge, Malvern -79.195517  43.811525
# 1               Highland Creek, Rouge Hill, Port Union -79.158725  43.785665
# 2                    Guildwood, Morningside, West Hill -79.175193  43.765815
# 3                                               Woburn -79.217590  43.768369
# 4                                            Cedarbrae -79.239440  43.769688
# 5                                  Scarborough Village -79.231750  43.743125
# 6          East Birchmount Park, Ionview, Kennedy Park -79.263625  43.726276
# 7                      Clairlea, Golden Mile, Oakridge -79.285055  43.713054
# 8      Cliffcrest, Cliffside, Scarborough Village West -79.227925  43.724235
# 9                          Birch Cliff, Cliffside West -79.259967  43.696770
# 10   Dorset Park, Scarborough Town Centre, Wexford ... -79.268974  43.759975
# 11                                   Maryvale, Wexford -79.300560  43.750710
# 12                                           Agincourt -79.267976  43.793940
# 13             Clarks Corners, Sullivan, Tam O'Shanter -79.299066  43.784725
# 14   Agincourt North, L'Amoreaux East, Milliken, St... -79.280187  43.817685
# 15                                     L'Amoreaux West -79.320740  43.800883
# 16                                         Upper Rouge -79.216701  43.834215
# 17                                   Hillcrest Village -79.356207  43.802845
# 18                        Fairview, Henry Farm, Oriole -79.347813  43.780970
# 19                                     Bayview Village -79.380529  43.781015
# 20                            Silver Hills, York Mills -79.380320  43.757095
# 21                             Newtonbrook, Willowdale -79.413605  43.791475
# 22                                    Willowdale South -79.407420  43.768165
# 23                                     York Mills West -79.399919  43.747895
# 24                                     Willowdale West -79.445797  43.777695
# 25                                           Parkwoods -79.329242  43.752420
# 26                                     Don Mills North -79.362227  43.749055
# 27                    Flemingdon Park, Don Mills South -79.343454  43.721425
# 28     Bathurst Manor, Downsview North, Wilson Heights -79.448688  43.757875
# 29                     Northwood Park, York University -79.488094  43.764765
# 30                         CFB Toronto, Downsview East -79.467320  43.738685
# 31                                      Downsview West -79.516980  43.720140
# 32                                   Downsview Central -79.496740  43.733690
# 33                                 Downsview Northwest -79.519590  43.755371
# 34                                    Victoria Village -79.313265  43.730600
# 35                     Woodbine Gardens, Parkview Hill -79.311773  43.707535
# 36                                    Woodbine Heights -79.306874  43.689640
# 37                                         The Beaches -79.295425  43.676531
# 38                                             Leaside -79.363989  43.709495
# 39                                    Thorncliffe Park -79.349825  43.701240
# 40                                        East Toronto -79.334175  43.688765
# 41                        The Danforth West, Riverdale -79.355105  43.683178
# 42                      The Beaches West, India Bazaar -79.314667  43.667965
# 43                                     Studio District -79.334855  43.660629
# 44                                       Lawrence Park -79.387133  43.728420
# 45                                    Davisville North -79.388514  43.712755
# 46                                  North Toronto West -79.406960  43.714523
# 47                                          Davisville -79.385964  43.703395
# 48                         Moore Park, Summerhill East -79.382946  43.690685
# 49   Deer Park, Forest Hill SE, Rathnelly, South Hi... -79.402265  43.686074
# 50                                            Rosedale -79.377945  43.682205
# 51                         Cabbagetown, St. James Town -79.366602  43.668160
# 52                                Church and Wellesley -79.381302  43.666585
# 53                                        Harbourfront -79.359166  43.650295
# 54                            Ryerson, Garden District -79.378180  43.657363
# 55                                      St. James Town -79.375481  43.651210
# 56                                         Berczy Park -79.373675  43.645160
# 57                                  Central Bay Street -79.384930  43.656091
# 58                            Adelaide, King, Richmond -79.382582  43.649700
# 59   Harbourfront East, Toronto Islands, Union Station -79.362433  43.630210
# 60            Design Exchange, Toronto Dominion Centre -79.381531  43.647100
# 61                      Commerce Court, Victoria Hotel -79.378865  43.648395
# 62                   Bedford Park, Lawrence Manor East -79.419148  43.735460
# 63                                            Roselawn -79.419120  43.711941
# 64                 Forest Hill North, Forest Hill West -79.414405  43.694785
# 65                 The Annex, North Midtown, Yorkville -79.403768  43.674840
# 66                      Harbord, University of Toronto -79.401801  43.663110
# 67           Chinatown, Grange Park, Kensington Market -79.397233  43.653530
# 68   CN Tower, Bathurst Quay, Island airport, Harbo... -79.399538  43.640815
# 69                     Stn A PO Boxes 25 The Esplanade -79.385440  43.648690
# 70              First Canadian Place, Underground city -79.381461  43.648280
# 71                    Lawrence Heights, Lawrence Manor -79.451286  43.723270
# 72                                           Glencairn -79.448367  43.707990
# 73                                  Humewood-Cedarvale -79.430355  43.692105
# 74                                 Caledonia-Fairbanks -79.451018  43.688640
# 75                                            Christie -79.420710  43.668781
# 76                        Dovercourt Village, Dufferin -79.438705  43.665087
# 77                            Little Portugal, Trinity -79.417757  43.648525
# 78        Brockton, Exhibition Place, Parkdale Village -79.424362  43.639410
# 79                  Downsview, North Park, Upwood Park -79.488301  43.713810
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn -79.484489  43.694530
# 81                       The Junction North, Runnymede -79.481932  43.676125
# 82                       High Park, The Junction South -79.463019  43.659935
# 83                              Parkdale, Roncesvalles -79.449776  43.647870
# 84                                  Runnymede, Swansea -79.476141  43.649620
# 85                                        Queen's Park -79.391715  43.661150
# 86               Canada Post Gateway Processing Centre -79.385440  43.648690
# 87   Business Reply Mail Processing Centre 969 Eastern -79.385440  43.648690
# 88        Humber Bay Shores, Mimico South, New Toronto -79.495146  43.612200
# 89                              Alderwood, Long Branch -79.538785  43.601131
# 90       The Kingsway, Montgomery Road, Old Mill North -79.510890  43.653760
# 91   Humber Bay, King's Mill Park, Kingsway Park So... -79.489550  43.632835
# 92   Kingsway Park South West, Mimico NW, The Queen... -79.526950  43.624630
# 93                                        Queen's Park -79.528195  43.662299
# 94   Cloverdale, Islington, Martin Grove, Princess ... -79.555040  43.650347
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol... -79.578250  43.648573
# 96                                       Humber Summit -79.557028  43.759500
# 97                                    Emery, Humberlea -79.537508  43.733705
# 98                                              Weston -79.517546  43.704845
# 99                                           Westmount -79.530252  43.696505
# 100  Kingsview Village, Martin Grove Gardens, Richv... -79.557284  43.686810
# 101  Albion Gardens, Beaumond Heights, Humbergate, ... -79.584664  43.743145
# 102                                          Northwest -79.579181  43.711740
